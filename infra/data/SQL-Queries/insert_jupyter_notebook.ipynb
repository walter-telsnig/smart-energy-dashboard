# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    conn.close()
except Exception as e:
     print("Error:", e)
# Out:
# Connection success

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../consumption/consumption_2025_dach_15min.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY consumption_minute
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../consumption/consumption_2026_dach_15min.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY consumption_minute
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../consumption/consumption_2027_dach_15min.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY consumption_minute
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../consumption/consumption_2025_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY consumption
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../consumption/consumption_2026_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY consumption
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../consumption/consumption_2027_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY consumption
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../market/price_2025_dach_15min.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY market_minute
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../market/price_2026_dach_15min.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY market_minute
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../market/price_2027_dach_15min.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY market_minute
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../market/price_2025_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY market
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
        with open("../market/price_2026_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY market
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../market/price_2027_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY market
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../pv/pv_2025_dach_15min.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY pv_minute
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../pv/pv_2026_dach_15min.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY pv_minute
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../pv/pv_2027_dach_15min.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY pv_minute
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../pv/pv_2025_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY pv
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../pv/pv_2026_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY pv
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../pv/pv_2027_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY pv
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../weather/weather_2025_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY weather
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../weather/weather_2026_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY weather
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!

# %%
import psycopg2
import pandas as pd

try:
    conn = psycopg2.connect(
        dbname="pv-db", user="postgres", password="ppswy2026", host="localhost"
    )
    print("Connection success")
    cur = conn.cursor()
    
    with open("../weather/weather_2027_hourly.csv", "r", encoding="utf-8") as f:
        cur.copy_expert("""
            COPY weather
            FROM STDIN
            WITH CSV HEADER
            NULL ''
        """, f)
    
    conn.commit()
    cur.close()
    conn.close()
    
    print("COPY transactions erfolgreich!")
except Exception as e:
     print("Error:", e)
# Out:
# Connection success
# COPY transactions erfolgreich!
